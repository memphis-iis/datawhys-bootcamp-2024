# %% [markdown]
# # User Activity 2 (Filtering 1)

# %% [markdown]
# ## Question: Given a dataset about childern's nursuries, find the best nurseries suitable for a child

# %% [markdown]
# We have this dataset named `nursery.csv` which has information about the quality of children's nurseries. We want to analyze this dataset to find the best nursery that is suitable for a child.
#
# **Dataset location:** datasets/nursery.csv

# %% [markdown]
# ### Step 1: Read CSV Data into Pandas Dataframe

# %% [markdown]
# #### Import Pandas Library

# %% [markdown]
# #!blhint
#
# - Create variable &nbsp;`pd`
# - `import pandas as pd`

# %% [markdown]
# <br>
# <details>
#     <summary>Blockly Hints (Click to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li><code>import .. as ..</code>
#                     <ul>
#                         <li>The <code>import .. as ..</code> block is found under IMPORT.</li>
#                         <li>A variable must have been created before it will appear in the dropdown.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

import pandas as pd

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="lW11(Qm@iU;/H##6Zc0-">pd</variable></variables><block type="importAs_Python" id="lmYn[NQOFv;#9.r1;d7V" x="16" y="8"><field name="libraryName">pandas</field><field name="libraryAlias" id="lW11(Qm@iU;/H##6Zc0-">pd</field></block></xml>

# %% [markdown]
# #### Read CSV data and Save in Variable

# %% [markdown]
# #!blhint
#
# - Create variable &nbsp;`nursery_data`
# - `set nursery_data to` &nbsp;:&nbsp; `with pd do read_csv using` &nbsp;<-&nbsp; `" datasets/nursery.csv "`

# %% [markdown]
# <br><details><summary>Blockly Hints (Click triangle to expand)</summary><ul><li>Notation<ul><li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li><li><code>A</code> &nbsp;&lt;-&nbsp; <code>B</code>&nbsp; means insert block B into the hole in block A.</li></ul></li><li>Blocks<ul><li><code>set .. to</code><ul><li>The <code>set .. to</code> block is found under VARIABLES.</li> <li>A variable must have been created before it will appear in the dropdown.</li></ul></li><li><code>with .. do .. using ..</code><ul><li>The <code>with .. do .. using ..</code> block is found under VARIABLES.</li> <li>If <code>do</code> dropdown says "!Not populated until you execute code", click anywhere in the notebook tab, then click try "Run All Above Selected Cell" from the "Run" menu.</li> <li>If <code>with .. do .. using ..</code> block does not want to snap together nicely with the <code>set .. to</code> block, try dragging the <code>set .. to</code> block instead.</li></ul></li><li><code>" .. "</code><ul><li>The <code>" .. "</code> block is found under TEXT.</li></ul></li></ul></li></ul></details>

# %%
#!response

nursery_data = pd.read_csv('datasets/nursery.csv')

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="=T6hu7S)F`e?LQ824eKP">nursery_data</variable><variable id="lW11(Qm@iU;/H##6Zc0-">pd</variable></variables><block type="variables_set" id="fmUW!@WWN#k8)7_XzUUI" x="13" y="205"><field name="VAR" id="=T6hu7S)F`e?LQ824eKP">nursery_data</field><value name="VALUE"><block type="varDoMethod_Python" id="%e-k4W1:73@9JLpf$?EM"><mutation items="1"></mutation><field name="VAR" id="lW11(Qm@iU;/H##6Zc0-">pd</field><field name="MEMBER">read_csv</field><data>pd:read_csv</data><value name="ADD0"><block type="text" id="XvW$`uDH5k^47z$AVwWx"><field name="TEXT">datasets/nursery.csv</field></block></value></block></value></block></xml>

# %% [markdown]
# #### Display nursery_data (dataframe content)

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`nursery_data`

# %% [markdown]
# <br>
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

nursery_data

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="=T6hu7S)F`e?LQ824eKP">nursery_data</variable></variables><block type="variables_get" id="#*Mvh6_P=nrVR~{BT8V*" x="11" y="186"><field name="VAR" id="=T6hu7S)F`e?LQ824eKP">nursery_data</field></block></xml>
# Out:
#           parents     has_nurs        form children     housing     finance  \
# 0     pretentious    very_crit    complete     more   less_conv  convenient
# 1     pretentious       proper      foster     more    critical  convenient
# 2     pretentious     critical      foster        3   less_conv  convenient
# 3      great_pret     critical   completed        3   less_conv  convenient
# 4           usual  less_proper  incomplete        3  convenient      inconv
# ...           ...          ...         ...      ...         ...         ...
# 1995   great_pret       proper    complete        1    critical      inconv
# 1996        usual     critical   completed        3  convenient      inconv
# 1997   great_pret  less_proper    complete        1  convenient  convenient
# 1998   great_pret       proper      foster        1    critical      inconv
# 1999        usual     critical  incomplete        2  convenient      inconv
#
#              social        heath     ranking
# 0       problematic    not_recom   not_recom
# 1     slightly_prob  recommended    priority
# 2     slightly_prob  recommended  spec_prior
# 3           nonprob    not_recom   not_recom
# 4     slightly_prob     priority    priority
# ...             ...          ...         ...
# 1995    problematic  recommended    priority
# 1996        nonprob    not_recom   not_recom
# 1997  slightly_prob     priority    priority
# 1998        nonprob  recommended    priority
# 1999  slightly_prob    not_recom   not_recom
#
# [2000 rows x 9 columns]

# %% [markdown]
# ### Step 2: Find the suitable nurseries

# %% [markdown]
# #### Get features (column names) of the dataframe

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`from nursery_data get columns`

# %% [markdown]
# <details>
# <summary> Blockly Instructions(click triangle to expand) </summary>
# <br>
#
# - `from.. get..` block can be found in VARIABLES menu of Blockly palette.
# - A variable must have been created before it will appear in the dropdown.
# - If dropdown says "!Not populated until you execute code", click anywhere in the notebook tab, then click try "Run All Above Selected Cell" from the "Run" menu.
#
# </details>

# %%
#!response

nursery_data.columns

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="=T6hu7S)F`e?LQ824eKP">nursery_data</variable></variables><block type="varGetProperty_Python" id="|i*agFI/tvs3$W?%n4)d" x="8" y="146"><field name="VAR" id="=T6hu7S)F`e?LQ824eKP">nursery_data</field><field name="MEMBER">columns</field><data>nursery_data:columns</data></block></xml>
# Out:
# Index(['parents', 'has_nurs', 'form', 'children', 'housing', 'finance',
#        'social', 'heath', 'ranking'],
#       dtype='object')

# %% [markdown]
# #### Find the `convenient` nursuries based on `finance` feature

# %% [markdown]
# Lets look at the columns. From these features, first, we want to look at the nurseries which are affordable. So, we look at the `finance` column and find the ones which are `convenient`.

# %% [markdown]
# #!blhint
# - create variable `convenient_places`
# - `Set convenient_places to` &nbsp;:&nbsp; `nursery_data [ .. ]` &nbsp;<-&nbsp; ` .. = .. ` &nbsp;<-
#   - `from nursery_data get finance`
#   - `convenient`
# - Will look like - `Set convenient_places to nursery_data [ from nursery_data get finance = convenient]`

# %% [markdown]
# <br>
# <details>
#   <summary>Blockly Hints (Click on the triangle to expand)</summary>
#   <ul>
#     <li>Notation
#       <ul>
#         <li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li>
#         <li><code>A</code> &nbsp;&lt;-&nbsp;<code>B</code>&nbsp; means insert block B into the hole in block A.</li>
#       </ul>
#     </li>
#     <li>Blocks
#       <ul>
#         <li><code>set .. to</code>
#           <ul>
#             <li>The <code>set .. to</code> block is found under VARIABLES.</li>
#             <li>A variable must have been created before it will appear in the dropdown.</li>
#           </ul>
#         </li>
#         <li><code>{dictVariable} [ .. ]</code>
#           <ul>
#             <li>The <code>{dictVariable} [ .. ]</code> block is found under LISTS.</li>
#           </ul>
#         </li>
#         <li><code> .. = .. </code>
#           <ul>
#             <li>The <code> .. = .. </code> block is found under LOGIC.</li>
#             <li>Use the dropdown to get other comparison operators.</li>
#           </ul>
#         </li>
#         <li><code>from .. get ..</code>
#           <ul>
#             <li>The <code>from .. get ..</code> block is found under VARIABLES.</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </details>

# %%
#!response

convenient_place = nursery_data[(nursery_data.finance == 'convenient')]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="EytG(38X?(fCwWm.+s*G">convenient_place</variable><variable id="=T6hu7S)F`e?LQ824eKP">nursery_data</variable></variables><block type="variables_set" id="5WtIc_3[!|cgOU=FEcfY" x="-45" y="137"><field name="VAR" id="EytG(38X?(fCwWm.+s*G">convenient_place</field><value name="VALUE"><block type="indexer_Python" id="TEmeS)}1+1uvWSyEx~fP"><field name="VAR" id="=T6hu7S)F`e?LQ824eKP">nursery_data</field><value name="INDEX"><block type="logic_compare" id="ywOor![Bfif2JNx:.E{b"><field name="OP">EQ</field><value name="A"><block type="varGetProperty_Python" id="7ugvdF)hR?Y5!m=Cc@G6"><field name="VAR" id="=T6hu7S)F`e?LQ824eKP">nursery_data</field><field name="MEMBER">finance</field><data>nursery_data:finance</data></block></value><value name="B"><block type="text" id="0Bu+k^YY77y.s*EDSH7{"><field name="TEXT">convenient</field></block></value></block></value></block></value></block></xml>

# %% [markdown]
# Now we want to display our variable in which we stored the convenient nursuries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`convenient_places`

# %% [markdown]
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

convenient_place

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="EytG(38X?(fCwWm.+s*G">convenient_place</variable></variables><block type="variables_get" id="4Q+S@JZJK=V=wp7^tnyk" x="-37" y="418"><field name="VAR" id="EytG(38X?(fCwWm.+s*G">convenient_place</field></block></xml>
# Out:
#           parents     has_nurs       form children     housing     finance  \
# 0     pretentious    very_crit   complete     more   less_conv  convenient
# 1     pretentious       proper     foster     more    critical  convenient
# 2     pretentious     critical     foster        3   less_conv  convenient
# 3      great_pret     critical  completed        3   less_conv  convenient
# 5     pretentious     improper     foster     more    critical  convenient
# ...           ...          ...        ...      ...         ...         ...
# 1981   great_pret  less_proper     foster        2  convenient  convenient
# 1983        usual    very_crit     foster        3    critical  convenient
# 1989        usual     critical     foster        1    critical  convenient
# 1991   great_pret     critical     foster        3    critical  convenient
# 1997   great_pret  less_proper   complete        1  convenient  convenient
#
#              social        heath     ranking
# 0       problematic    not_recom   not_recom
# 1     slightly_prob  recommended    priority
# 2     slightly_prob  recommended  spec_prior
# 3           nonprob    not_recom   not_recom
# 5     slightly_prob  recommended    priority
# ...             ...          ...         ...
# 1981    problematic    not_recom   not_recom
# 1983    problematic     priority  spec_prior
# 1989  slightly_prob    not_recom   not_recom
# 1991  slightly_prob    not_recom   not_recom
# 1997  slightly_prob     priority    priority
#
# [976 rows x 9 columns]

# %% [markdown]
# #### Remove the `not_recom` nursuries based on `ranking` feature

# %% [markdown]
# Now we are concerned about the rank of the nurseries. We don't want the ones which are not recommended. So, we look into `ranking` column and filter out the not recommended `not_recom` ones from our list.

# %% [markdown]
# #!blhint
# - create variable `ranked`
# - `Set ranked to` &nbsp;:&nbsp; `convenient_places [ .. ]` &nbsp;<-&nbsp; ` .. = .. ` &nbsp;<-
#   - `from convenient_places get ranking`
#   - `"not_recom"`
# - Will look like - `Set ranked to convenient_places [ from convenient_places get ranking ≠ "not_recom"]`

# %% [markdown]
# <br>
# <details>
#   <summary>Blockly Hints (Click on the triangle to expand)</summary>
#   <ul>
#     <li>Notation
#       <ul>
#         <li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li>
#         <li><code>A</code>&nbsp;&lt;-&nbsp; <code>B</code>&nbsp; means insert block B into the hole in block A.</li>
#       </ul>
#     </li>
#     <li>Blocks
#       <ul>
#         <li><code>set .. to</code>
#           <ul>
#             <li>The <code>set .. to</code> block is found under VARIABLES.</li>
#             <li>A variable must have been created before it will appear in the dropdown.</li>
#           </ul>
#         </li>
#         <li><code>{dictVariable} [ .. ]</code>
#           <ul>
#             <li>The <code>{dictVariable} [ .. ]</code> block is found under LISTS.</li>
#           </ul>
#         </li>
#         <li><code> .. = .. </code>
#           <ul>
#             <li>The <code> .. = .. </code> block is found under LOGIC.</li>
#             <li>Use the dropdown to get `≠` comparison operators.</li>
#           </ul>
#         </li>
#         <li><code>from .. get ..</code>
#           <ul>
#             <li>The <code>from .. get ..</code> block is found under VARIABLES.</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </details>

# %%
#!response

ranked = convenient_place[(convenient_place.ranking != 'not_recom')]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="Wf9kEA9DNG8VuqdJF(eC">ranked</variable><variable id="EytG(38X?(fCwWm.+s*G">convenient_place</variable></variables><block type="variables_set" id="uF0Tiy:-X+fs7*unMxwz" x="-46" y="280"><field name="VAR" id="Wf9kEA9DNG8VuqdJF(eC">ranked</field><value name="VALUE"><block type="indexer_Python" id="q)qZ:Ux{a%sul|FOc-K@"><field name="VAR" id="EytG(38X?(fCwWm.+s*G">convenient_place</field><value name="INDEX"><block type="logic_compare" id="%t6{QLKv7:hgC~]%h`Ah"><field name="OP">NEQ</field><value name="A"><block type="varGetProperty_Python" id="wjk$)xV6mfs_qhB$_71N"><field name="VAR" id="EytG(38X?(fCwWm.+s*G">convenient_place</field><field name="MEMBER">ranking</field><data>convenient_place:ranking</data></block></value><value name="B"><block type="text" id="8|%pT?C$:zqd@OQvdndq"><field name="TEXT">not_recom</field></block></value></block></value></block></value></block></xml>

# %% [markdown]
# Now we want to display our `ranked` variable in which we stored the desired nurseries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`ranked`

# %% [markdown]
# <br>
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

ranked

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="Wf9kEA9DNG8VuqdJF(eC">ranked</variable></variables><block type="variables_get" id="MN{c1.7png%$3|-@]$=|" x="-21" y="188"><field name="VAR" id="Wf9kEA9DNG8VuqdJF(eC">ranked</field></block></xml>
# Out:
#           parents     has_nurs        form children     housing     finance  \
# 1     pretentious       proper      foster     more    critical  convenient
# 2     pretentious     critical      foster        3   less_conv  convenient
# 5     pretentious     improper      foster     more    critical  convenient
# 6           usual    very_crit   completed     more  convenient  convenient
# 8      great_pret  less_proper   completed        1    critical  convenient
# ...           ...          ...         ...      ...         ...         ...
# 1973        usual     critical   completed     more  convenient  convenient
# 1975  pretentious       proper    complete     more  convenient  convenient
# 1980  pretentious     critical  incomplete        1  convenient  convenient
# 1983        usual    very_crit      foster        3    critical  convenient
# 1997   great_pret  less_proper    complete        1  convenient  convenient
#
#              social        heath     ranking
# 1     slightly_prob  recommended    priority
# 2     slightly_prob  recommended  spec_prior
# 5     slightly_prob  recommended    priority
# 6           nonprob  recommended    priority
# 8           nonprob     priority  spec_prior
# ...             ...          ...         ...
# 1973    problematic     priority    priority
# 1975  slightly_prob  recommended  very_recom
# 1980    problematic     priority  spec_prior
# 1983    problematic     priority  spec_prior
# 1997  slightly_prob     priority    priority
#
# [631 rows x 9 columns]

# %% [markdown]
# #### Remove the `critical` nursuries based on `housing` feature

# %% [markdown]
# Now, from our new list, we want nurseries with good housing qualities. But, there are some nurseries in `critical` condition, so we need to look into `housing` column and remove those `critical` nurseries from our list.

# %% [markdown]
# #!blhint
# - create variable `good_housing`
# - `Set good_housing to` &nbsp;:&nbsp; `ranked [ .. ]` &nbsp;<-&nbsp; ` .. = .. ` &nbsp;<-
#   - `from ranked get housing`
#   - `"critical"`
# - Will look like - `Set good_housing to ranked [ from ranked get housing ≠ "critical"]`

# %% [markdown]
# <br>
# <details>
#   <summary>Blockly Hints (Click on the triangle to expand)</summary>
#   <ul>
#     <li>Notation
#       <ul>
#         <li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li>
#         <li><code>A</code>&nbsp;&lt;-&nbsp; <code>B</code>&nbsp; means insert block B into the hole in block A.</li>
#       </ul>
#     </li>
#     <li>Blocks
#       <ul>
#         <li><code>set .. to</code>
#           <ul>
#             <li>The <code>set .. to</code> block is found under VARIABLES.</li>
#             <li>A variable must have been created before it will appear in the dropdown.</li>
#           </ul>
#         </li>
#         <li><code>{dictVariable} [ .. ]</code>
#           <ul>
#             <li>The <code>{dictVariable} [ .. ]</code> block is found under LISTS.</li>
#           </ul>
#         </li>
#         <li><code> .. = .. </code>
#           <ul>
#             <li>The <code> .. = .. </code> block is found under LOGIC.</li>
#             <li>Use the dropdown to get `≠` comparison operators.</li>
#           </ul>
#         </li>
#         <li><code>from .. get ..</code>
#           <ul>
#             <li>The <code>from .. get ..</code> block is found under VARIABLES.</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </details>

# %%
#!response

good_housing = ranked[(ranked.housing == 'critical')]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="wusP_ML:;K4%Ah-Zq{;P">good_housing</variable><variable id="Wf9kEA9DNG8VuqdJF(eC">ranked</variable></variables><block type="variables_set" id="aU(G7y@nA~4:DG5;l_eW" x="-25" y="172"><field name="VAR" id="wusP_ML:;K4%Ah-Zq{;P">good_housing</field><value name="VALUE"><block type="indexer_Python" id="|@CKT4#$D.N}X4=K($UP"><field name="VAR" id="Wf9kEA9DNG8VuqdJF(eC">ranked</field><value name="INDEX"><block type="logic_compare" id="f7Yxwbs6zr({e9kGD.(F"><field name="OP">EQ</field><value name="A"><block type="varGetProperty_Python" id="?{JVkpi()2.?JD86;C|/"><field name="VAR" id="Wf9kEA9DNG8VuqdJF(eC">ranked</field><field name="MEMBER">housing</field><data>ranked:housing</data></block></value><value name="B"><block type="text" id="h]g=JA{Rn[5LF!sy0b@:"><field name="TEXT">critical</field></block></value></block></value></block></value></block></xml>

# %% [markdown]
# Now we want to display our `good_housing` variable in which we stored the desired nurseries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`good_housing`

# %% [markdown]
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

good_housing

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="wusP_ML:;K4%Ah-Zq{;P">good_housing</variable></variables><block type="variables_get" id="Dq}vveS*:.z0~)@Jxkna" x="-16" y="155"><field name="VAR" id="wusP_ML:;K4%Ah-Zq{;P">good_housing</field></block></xml>
# Out:
#           parents     has_nurs        form children   housing     finance  \
# 1     pretentious       proper      foster     more  critical  convenient
# 5     pretentious     improper      foster     more  critical  convenient
# 8      great_pret  less_proper   completed        1  critical  convenient
# 15          usual       proper  incomplete     more  critical  convenient
# 19     great_pret       proper  incomplete        1  critical  convenient
# ...           ...          ...         ...      ...       ...         ...
# 1943  pretentious    very_crit    complete        1  critical  convenient
# 1950  pretentious     improper   completed        3  critical  convenient
# 1951   great_pret  less_proper      foster        3  critical  convenient
# 1953  pretentious    very_crit    complete        1  critical  convenient
# 1983        usual    very_crit      foster        3  critical  convenient
#
#              social        heath     ranking
# 1     slightly_prob  recommended    priority
# 5     slightly_prob  recommended    priority
# 8           nonprob     priority  spec_prior
# 15          nonprob     priority    priority
# 19      problematic  recommended  spec_prior
# ...             ...          ...         ...
# 1943  slightly_prob  recommended    priority
# 1950        nonprob     priority  spec_prior
# 1951        nonprob  recommended    priority
# 1953    problematic     priority  spec_prior
# 1983    problematic     priority  spec_prior
#
# [215 rows x 9 columns]

# %% [markdown]
# #### Find the `proper` care nursuries based on `has_nurs` feature

# %% [markdown]
# For our next step, choose the nurseries which have adequate nurses in them to ensure `proper` care. We will look into `has_nurs` column to find the nurseries with `proper` care.

# %% [markdown]
# #!blhint
# - create variable `proper_nurse`
# - `Set proper_nurse to` &nbsp;:&nbsp; `good_housing [ .. ]` &nbsp;<-&nbsp; ` .. = .. ` &nbsp;<-
#   - `from good_housing get has_nurs`
#   - `"proper"`
# - Will look like - `Set proper_nurse to good_housing [ from good_housing get has_nurs = "proper"]`

# %% [markdown]
# <br>
# <details>
#   <summary>Blockly Hints (Click on the triangle to expand)</summary>
#   <ul>
#     <li>Notation
#       <ul>
#         <li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li>
#         <li><code>A</code>&nbsp;&lt;-&nbsp; <code>B</code>&nbsp; means insert block B into the hole in block A.</li>
#       </ul>
#     </li>
#     <li>Blocks
#       <ul>
#         <li><code>set .. to</code>
#           <ul>
#             <li>The <code>set .. to</code> block is found under VARIABLES.</li>
#             <li>A variable must have been created before it will appear in the dropdown.</li>
#           </ul>
#         </li>
#         <li><code>{dictVariable} [ .. ]</code>
#           <ul>
#             <li>The <code>{dictVariable} [ .. ]</code> block is found under LISTS.</li>
#           </ul>
#         </li>
#         <li><code> .. = .. </code>
#           <ul>
#             <li>The <code> .. = .. </code> block is found under LOGIC.</li>
#             <li>Use the dropdown to get other comparison operators.</li>
#           </ul>
#         </li>
#         <li><code>from .. get ..</code>
#           <ul>
#             <li>The <code>from .. get ..</code> block is found under VARIABLES.</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </details>

# %%
#!response

proper_nurse = good_housing[(good_housing.has_nurs == 'proper')]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</variable><variable id="wusP_ML:;K4%Ah-Zq{;P">good_housing</variable></variables><block type="variables_set" id="IB7VRflE:;#P26)U,qJO" x="-257" y="165"><field name="VAR" id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</field><value name="VALUE"><block type="indexer_Python" id="|}:pD}w6{;dPw90f6nBS"><field name="VAR" id="wusP_ML:;K4%Ah-Zq{;P">good_housing</field><value name="INDEX"><block type="logic_compare" id="l~I!yQ08BjCS`*m=O*Vl"><field name="OP">EQ</field><value name="A"><block type="varGetProperty_Python" id="OnMpmrhns?kj-Sj(.^xk"><field name="VAR" id="wusP_ML:;K4%Ah-Zq{;P">good_housing</field><field name="MEMBER">has_nurs</field><data>good_housing:has_nurs</data></block></value><value name="B"><block type="text" id="r*;g!gm@,/[tr$zV2^r|"><field name="TEXT">proper</field></block></value></block></value></block></value></block></xml>

# %% [markdown]
# Now we want to display our `proper_nurse` variable in which we stored the desired nurseries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`proper_nurse`

# %% [markdown]
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

proper_nurse

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</variable></variables><block type="variables_get" id="4Yk;b{O/BN94:gYQF.pZ" x="-208" y="545"><field name="VAR" id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</field></block></xml>
# Out:
#           parents has_nurs        form children   housing     finance  \
# 1     pretentious   proper      foster     more  critical  convenient
# 15          usual   proper  incomplete     more  critical  convenient
# 19     great_pret   proper  incomplete        1  critical  convenient
# 31          usual   proper  incomplete        3  critical  convenient
# 70     great_pret   proper   completed        1  critical  convenient
# 81          usual   proper      foster        1  critical  convenient
# 156    great_pret   proper   completed     more  critical  convenient
# 186   pretentious   proper    complete        1  critical  convenient
# 240    great_pret   proper   completed        2  critical  convenient
# 247    great_pret   proper    complete     more  critical  convenient
# 256    great_pret   proper    complete        1  critical  convenient
# 270   pretentious   proper  incomplete        2  critical  convenient
# 289    great_pret   proper    complete        1  critical  convenient
# 356    great_pret   proper   completed        2  critical  convenient
# 392    great_pret   proper      foster        2  critical  convenient
# 494   pretentious   proper      foster     more  critical  convenient
# 517         usual   proper  incomplete        1  critical  convenient
# 524    great_pret   proper  incomplete     more  critical  convenient
# 540         usual   proper   completed        2  critical  convenient
# 552   pretentious   proper    complete     more  critical  convenient
# 587         usual   proper  incomplete     more  critical  convenient
# 610         usual   proper      foster        2  critical  convenient
# 629         usual   proper   completed        3  critical  convenient
# 649    great_pret   proper      foster        1  critical  convenient
# 676    great_pret   proper      foster     more  critical  convenient
# 697         usual   proper  incomplete        1  critical  convenient
# 828         usual   proper      foster        3  critical  convenient
# 876    great_pret   proper  incomplete        2  critical  convenient
# 1028  pretentious   proper    complete     more  critical  convenient
# 1136        usual   proper    complete        3  critical  convenient
# 1309        usual   proper      foster        3  critical  convenient
# 1417  pretentious   proper      foster        1  critical  convenient
# 1466   great_pret   proper   completed     more  critical  convenient
# 1479   great_pret   proper   completed     more  critical  convenient
# 1490   great_pret   proper   completed        1  critical  convenient
# 1609   great_pret   proper      foster        3  critical  convenient
# 1613        usual   proper  incomplete        3  critical  convenient
# 1637   great_pret   proper   completed        3  critical  convenient
# 1656   great_pret   proper  incomplete     more  critical  convenient
# 1676        usual   proper    complete     more  critical  convenient
# 1740  pretentious   proper   completed        1  critical  convenient
# 1791   great_pret   proper  incomplete        2  critical  convenient
# 1854   great_pret   proper   completed     more  critical  convenient
# 1866        usual   proper    complete        1  critical  convenient
#
#              social        heath     ranking
# 1     slightly_prob  recommended    priority
# 15          nonprob     priority    priority
# 19      problematic  recommended  spec_prior
# 31    slightly_prob  recommended    priority
# 70          nonprob     priority  spec_prior
# 81          nonprob  recommended    priority
# 156         nonprob  recommended    priority
# 186     problematic  recommended    priority
# 240         nonprob     priority  spec_prior
# 247     problematic     priority  spec_prior
# 256   slightly_prob  recommended    priority
# 270     problematic  recommended    priority
# 289     problematic  recommended    priority
# 356     problematic     priority  spec_prior
# 392         nonprob  recommended    priority
# 494         nonprob     priority    priority
# 517         nonprob     priority    priority
# 524         nonprob  recommended    priority
# 540     problematic  recommended    priority
# 552         nonprob  recommended    priority
# 587   slightly_prob     priority    priority
# 610     problematic  recommended    priority
# 629         nonprob     priority    priority
# 649   slightly_prob     priority  spec_prior
# 676     problematic     priority  spec_prior
# 697     problematic  recommended    priority
# 828   slightly_prob     priority    priority
# 876   slightly_prob     priority  spec_prior
# 1028  slightly_prob     priority    priority
# 1136    problematic     priority    priority
# 1309    problematic  recommended    priority
# 1417  slightly_prob  recommended    priority
# 1466    problematic     priority  spec_prior
# 1479  slightly_prob  recommended    priority
# 1490        nonprob  recommended    priority
# 1609        nonprob     priority  spec_prior
# 1613  slightly_prob     priority    priority
# 1637        nonprob     priority  spec_prior
# 1656        nonprob     priority  spec_prior
# 1676    problematic     priority    priority
# 1740  slightly_prob     priority    priority
# 1791  slightly_prob  recommended    priority
# 1854    problematic  recommended  spec_prior
# 1866        nonprob     priority    priority

# %% [markdown]
# #### Find the nursuries where there are `more` children based on `children` feature

# %% [markdown]
# Now, our final criteria is we want a nursery where there are more children which will help a child to get better at communication and also learn to share with each other. So, we will look into `children` cloumn and filter the nurseries which have `more` children.

# %% [markdown]
# #!blhint
# - create variable `more_children`
# - `Set more_children to` &nbsp;:&nbsp; `proper_nurse [ .. ]` &nbsp;<-&nbsp; ` .. = .. ` &nbsp;<-
#   - `from proper_nurse get children`
#   - `"more"`
# - Will look like - `Set more_children to proper_nurse [ from proper_nurse get children = "more"]`

# %% [markdown]
# <br>
# <details>
#   <summary>Blockly Hints (Click on the triangle to expand)</summary>
#   <ul>
#     <li>Notation
#       <ul>
#         <li><code>A</code> &nbsp;:&nbsp; <code>B</code>&nbsp; means snap blocks A and B together.</li>
#         <li><code>A</code>&nbsp;&lt;-&nbsp; <code>B</code>&nbsp; means insert block B into the hole in block A.</li>
#       </ul>
#     </li>
#     <li>Blocks
#       <ul>
#         <li><code>set .. to</code>
#           <ul>
#             <li>The <code>set .. to</code> block is found under VARIABLES.</li>
#             <li>A variable must have been created before it will appear in the dropdown.</li>
#           </ul>
#         </li>
#         <li><code>{dictVariable} [ .. ]</code>
#           <ul>
#             <li>The <code>{dictVariable} [ .. ]</code> block is found under LISTS.</li>
#           </ul>
#         </li>
#         <li><code> .. = .. </code>
#           <ul>
#             <li>The <code> .. = .. </code> block is found under LOGIC.</li>
#             <li>Use the dropdown to get other comparison operators.</li>
#           </ul>
#         </li>
#         <li><code>from .. get ..</code>
#           <ul>
#             <li>The <code>from .. get ..</code> block is found under VARIABLES.</li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </details>

# %%
#!response

more__children = proper_nurse[(proper_nurse.children == 'more')]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="s}pJ!]~uYe2X|(Z=x_+=">more _children</variable><variable id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</variable></variables><block type="variables_set" id="11w9U0}Kg8~JUOa.VR74" x="-199" y="149"><field name="VAR" id="s}pJ!]~uYe2X|(Z=x_+=">more _children</field><value name="VALUE"><block type="indexer_Python" id="J%%/3Ui+`L)]4hz[[n7C"><field name="VAR" id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</field><value name="INDEX"><block type="logic_compare" id="X9TO3(Fzi6TO0{@1eu^U"><field name="OP">EQ</field><value name="A"><block type="varGetProperty_Python" id="23X*AXH+,A:B#JS`DSWS"><field name="VAR" id="tWu6FNQ^q*t$1jwPQZ#d">proper_nurse</field><field name="MEMBER">children</field><data>proper_nurse:children</data></block></value><value name="B"><block type="text" id="637m{0DG31,dtSChP;m!"><field name="TEXT">more</field></block></value></block></value></block></value></block></xml>

# %% [markdown]
# Now we want to display our `more_children` variable in which we stored the desired nurseries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`more_children`

# %% [markdown]
# <details>
#     <summary>Blockly Hints (Click on triangle to expand)</summary>
#     <ul>
#         <li>Blocks
#             <ul>
#                 <li>variable
#                     <ul>
#                         <li>After it is created, each variable has its own block at the end of the VARIABLES menu.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>

# %%
#!response

more__children

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="s}pJ!]~uYe2X|(Z=x_+=">more _children</variable></variables><block type="variables_get" id="2(pc4f%H8RmPm8pquf|." x="-181" y="147"><field name="VAR" id="s}pJ!]~uYe2X|(Z=x_+=">more _children</field></block></xml>
# Out:
#           parents has_nurs        form children   housing     finance  \
# 1     pretentious   proper      foster     more  critical  convenient
# 15          usual   proper  incomplete     more  critical  convenient
# 156    great_pret   proper   completed     more  critical  convenient
# 247    great_pret   proper    complete     more  critical  convenient
# 494   pretentious   proper      foster     more  critical  convenient
# 524    great_pret   proper  incomplete     more  critical  convenient
# 552   pretentious   proper    complete     more  critical  convenient
# 587         usual   proper  incomplete     more  critical  convenient
# 676    great_pret   proper      foster     more  critical  convenient
# 1028  pretentious   proper    complete     more  critical  convenient
# 1466   great_pret   proper   completed     more  critical  convenient
# 1479   great_pret   proper   completed     more  critical  convenient
# 1656   great_pret   proper  incomplete     more  critical  convenient
# 1676        usual   proper    complete     more  critical  convenient
# 1854   great_pret   proper   completed     more  critical  convenient
#
#              social        heath     ranking
# 1     slightly_prob  recommended    priority
# 15          nonprob     priority    priority
# 156         nonprob  recommended    priority
# 247     problematic     priority  spec_prior
# 494         nonprob     priority    priority
# 524         nonprob  recommended    priority
# 552         nonprob  recommended    priority
# 587   slightly_prob     priority    priority
# 676     problematic     priority  spec_prior
# 1028  slightly_prob     priority    priority
# 1466    problematic     priority  spec_prior
# 1479  slightly_prob  recommended    priority
# 1656        nonprob     priority  spec_prior
# 1676    problematic     priority    priority
# 1854    problematic  recommended  spec_prior

# %% [markdown]
# ### Get the final output row counts

# %% [markdown]
# We have filtered the nurseries based on our desired features and the final desired nurseries are stored in `more_children` variable. Now we want get the count of such desired nurseries.

# %% [markdown]
# #!blhint
#
# - variable &nbsp;`from more_children get shape`

# %% [markdown]
# <details>
# <summary> Blockly Instructions(click triangle to expand) </summary>
# <br>
#
# - `from ...get...` can be found under `VARIABLE` menu.
# - A variable must have been created before it will appear in the dropdown.
# - If dropdown says "!Not populated until you execute code", click anywhere in the notebook tab, then click try "Run All Above Selected Cell" from the "Run" menu.
#
# </details>

# %%
#!response

# %% [markdown]
# How many rows did we finally get in the final result?

# %% [markdown]
# #!response
#
# Ans:
